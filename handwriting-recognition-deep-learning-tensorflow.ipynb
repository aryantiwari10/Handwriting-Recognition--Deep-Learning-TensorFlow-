# %% [markdown]
# # **Handwriting Recognition - TensorFlow**

# %% [markdown]
# ![](https://img.favpng.com/8/2/22/input-device-handwriting-recognition-digital-pen-png-favpng-rgu2P2MfvDMT0P5a85nXWjbFH.jpg)

# %% [markdown]
# # **IMPORTING THE LIBRARIES**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import scipy as sp
import warnings
import tensorflow as tf
import string
import datetime
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# # **LOADING THE DATASET**

# %%
train = pd.read_csv('/kaggle/input/handwriting-recognition/written_name_train_v2.csv')
valid = pd.read_csv('/kaggle/input/handwriting-recognition/written_name_validation_v2.csv')

# %%
train.head()
# Out:
#           FILENAME   IDENTITY
# 0  TRAIN_00001.jpg  BALTHAZAR
# 1  TRAIN_00002.jpg      SIMON
# 2  TRAIN_00003.jpg      BENES
# 3  TRAIN_00004.jpg    LA LOVE
# 4  TRAIN_00005.jpg     DAPHNE

# %%
valid.head()
# Out:
#               FILENAME    IDENTITY
# 0  VALIDATION_0001.jpg       BILEL
# 1  VALIDATION_0002.jpg  LAUMIONIER
# 2  VALIDATION_0003.jpg         LEA
# 3  VALIDATION_0004.jpg   JEAN-ROCH
# 4  VALIDATION_0005.jpg        RUPP

# %%
train.describe()
# Out:
#                FILENAME IDENTITY
# count            330961   330396
# unique           330961   100539
# top     TRAIN_83121.jpg   THOMAS
# freq                  1     1825

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330961 entries, 0 to 330960
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   FILENAME  330961 non-null  object
#  1   IDENTITY  330396 non-null  object
# dtypes: object(2)
# memory usage: 5.1+ MB

# %%
train.shape
# Out:
# (330961, 2)

# %%
valid.shape
# Out:
# (41370, 2)

# %%
train.value_counts()
# Out:
# FILENAME          IDENTITY
# TRAIN_00001.jpg   BALTHAZAR    1
# TRAIN_291526.jpg  CAMPOURCY    1
# TRAIN_291506.jpg  BELLO        1
# TRAIN_291505.jpg  BOISSIERE    1
# TRAIN_291504.jpg  LOUNA        1
#                               ..
# TRAIN_191201.jpg  CHOMEL       1
# TRAIN_191200.jpg  BARDIN       1
# TRAIN_19120.jpg   LAURI-ANN    1
# TRAIN_191199.jpg  TILLEMAN     1
# TRAIN_99999.jpg   DIMITRI      1
# Length: 330396, dtype: int64

# %%
train.dtypes
# Out:
# FILENAME    object
# IDENTITY    object
# dtype: object

# %%
valid.dtypes
# Out:
# FILENAME    object
# IDENTITY    object
# dtype: object

# %%
valid.columns
# Out:
# Index(['FILENAME', 'IDENTITY'], dtype='object')

# %%
train.columns
# Out:
# Index(['FILENAME', 'IDENTITY'], dtype='object')

# %% [markdown]
# **Checking Null Values**

# %%
train.isnull().sum()
# Out:
# FILENAME      0
# IDENTITY    565
# dtype: int64

# %%
valid.isnull().sum()
# Out:
# FILENAME     0
# IDENTITY    78
# dtype: int64

# %%
train.isnull().any()
# Out:
# FILENAME    False
# IDENTITY     True
# dtype: bool

# %% [markdown]
# **Our dataset contains some null values we have to drop them.**

# %% [markdown]
# **Dropping Null Values**

# %%
train=train.dropna()

# %%
valid=valid.dropna()

# %%
train.isnull().sum()
# Out:
# FILENAME    0
# IDENTITY    0
# dtype: int64

# %%
valid.isnull().sum()
# Out:
# FILENAME    0
# IDENTITY    0
# dtype: int64

# %%
train.isnull().any()
# Out:
# FILENAME    False
# IDENTITY    False
# dtype: bool

# %% [markdown]
# **Thus all the null values have been dropped.**

# %% [markdown]
# **Data Pre Processing**

# %%
#lets find the categorialfeatures
list_1=list(train.columns)

# %%
list_cate=[]
for i in list_1:
    if train[i].dtype=='object':
        list_cate.append(i)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for i in list_cate:
    train[i]=le.fit_transform(train[i])

# %%
train
# Out:
#         FILENAME  IDENTITY
# 0              0      6790
# 1              1     88373
# 2              2      9411
# 3              3     54452
# 4              4     24870
# ...          ...       ...
# 330956    263609     59046
# 330957    263610     92820
# 330958    263611     23178
# 330959    263613     70125
# 330960    263614     46219
#
# [330396 rows x 2 columns]

# %%
X = train.drop('FILENAME',axis=1)
y = train['FILENAME']

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [markdown]
# **HISTOGRAM**

# %%
train.hist(figsize=(14,12))
plt.show()

# %%
train.corr()
# Out:
#           FILENAME  IDENTITY
# FILENAME  1.000000  0.000385
# IDENTITY  0.000385  1.000000

# %% [markdown]
# **HEATMAP**

# %%
plt.figure(figsize = (12,10))

sns.heatmap(train.corr(), annot =True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **BOXPLOT**

# %%
plt.figure(figsize=(14,10))
sns.set_style(style='whitegrid')
plt.subplot(2,3,1)
sns.boxplot(x='FILENAME',data=train)
plt.subplot(2,3,2)
sns.boxplot(x='IDENTITY',data=train)
# Out:
# <AxesSubplot:xlabel='IDENTITY'>

# %%
train['IDENTITY'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# **BARPLOT**

# %%
plt.style.use("default")
sns.barplot(x="IDENTITY", y="FILENAME",data=train[180:190])
plt.title("Identity vs Filename",fontsize=15)
plt.xlabel("Identity")
plt.ylabel("Filename")
plt.show()

# %%
plt.style.use("default")
sns.barplot(x="FILENAME", y="IDENTITY",data=train[180:190])
plt.title("Filename vs Identity",fontsize=15)
plt.xlabel("Filename")
plt.ylabel("Identity")
plt.show()

# %% [markdown]
# **LINEPLOT**

# %%
plt.style.use("default")
plt.figure(figsize=(14,7))
sns.lineplot(x = "FILENAME",y = "IDENTITY",data = train[190:400], color='g')
plt.title("Filename vs Identity")
plt.xlabel("Filename")
plt.ylabel("Identity")
plt.show()

# %% [markdown]
# **KDE PLOT**

# %%
plt.style.use("default")
plt.figure(figsize=(14,8))
plt.xlabel('Identity')
plt.ylabel('Filename')
sns.kdeplot(train['IDENTITY'],shade=True,color='g')
plt.show()

# %% [markdown]
# **SCATTER PLOT**

# %%
sns.scatterplot(x='FILENAME',y="IDENTITY",data=train)
# Out:
# <AxesSubplot:xlabel='FILENAME', ylabel='IDENTITY'>

# %% [markdown]
# **TRAINING AND TESTING DATA**

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=12)

# %%
print(len(X_train))
print(len(X_test))
print(len(y_train))
print(len(y_test))
# Out:
# 231277
# 99119
# 231277
# 99119

# %% [markdown]
# **TENSORFLOW**

# %%
from tensorflow import keras
from tensorflow.keras import layers
model = tf.keras.Sequential([
      tf.keras.layers.Dense(units=80,activation='relu',name = 'input_layer'),
      tf.keras.layers.Dense(units=60,activation='relu',name = 'dense_layer1'),
      tf.keras.layers.Dense(units=40,activation='relu',name = 'dense_layer2'),
      tf.keras.layers.Dense(units=1,name='Output_layer')
],name='Model')   # Dropout and Batch Normalization can also be used.


        
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',        # In loss mae can also be used.
    metrics=['binary_accuracy'],
)


history = model.fit(X_train,y_train,batch_size=256,
    epochs=150,
)
# Out:
# Epoch 1/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2548568.0950 - binary_accuracy: 0.0000e+00
# Epoch 2/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2551710.5036 - binary_accuracy: 0.0000e+00
# Epoch 3/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2554824.0030 - binary_accuracy: 0.0000e+00
# Epoch 4/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2543600.4801 - binary_accuracy: 0.0000e+00
# Epoch 5/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2553299.7110 - binary_accuracy: 0.0000e+00
# Epoch 6/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2548615.0718 - binary_accuracy: 0.0000e+00
# Epoch 7/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2547006.9041 - binary_accuracy: 0.0000e+00
# Epoch 8/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2552933.4845 - binary_accuracy: 0.0000e+00
# Epoch 9/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2550650.5887 - binary_accuracy: 0.0000e+00
# Epoch 10/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2544706.3613 - binary_accuracy: 0.0000e+00
# Epoch 11/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2549694.2196 - binary_accuracy: 0.0000e+00
# Epoch 12/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2550436.0088 - binary_accuracy: 0.0000e+00
# Epoch 13/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2550791.2956 - binary_accuracy: 0.0000e+00
# Epoch 14/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2546766.1464 - binary_accuracy: 0.0000e+00
# Epoch 15/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2547987.9564 - binary_accuracy: 0.0000e+00
# Epoch 16/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2551631.1776 - binary_accuracy: 0.0000e+00
# Epoch 17/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2552478.4177 - binary_accuracy: 0.0000e+00
# Epoch 18/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2545071.2610 - binary_accuracy: 0.0000e+00
# Epoch 19/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2551083.8141 - binary_accuracy: 0.0000e+00
# Epoch 20/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2557652.3588 - binary_accuracy: 0.0000e+00
# Epoch 21/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2547073.8191 - binary_accuracy: 0.0000e+00
# Epoch 22/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2546205.8815 - binary_accuracy: 0.0000e+00
# Epoch 23/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2545017.3146 - binary_accuracy: 0.0000e+00
# Epoch 24/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2551734.3599 - binary_accuracy: 0.0000e+00
# Epoch 25/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2545178.5757 - binary_accuracy: 0.0000e+00
# Epoch 26/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2551607.5224 - binary_accuracy: 0.0000e+00
# Epoch 27/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2553602.0757 - binary_accuracy: 0.0000e+00
# Epoch 28/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2553857.2058 - binary_accuracy: 0.0000e+00
# Epoch 29/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2551832.7345 - binary_accuracy: 0.0000e+00
# Epoch 30/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2548886.1876 - binary_accuracy: 0.0000e+00
# Epoch 31/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2550212.8660 - binary_accuracy: 0.0000e+00
# Epoch 32/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2544575.4660 - binary_accuracy: 0.0000e+00
# Epoch 33/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2549007.7050 - binary_accuracy: 0.0000e+00
# Epoch 34/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2549606.3757 - binary_accuracy: 0.0000e+00
# Epoch 35/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2548074.1986 - binary_accuracy: 0.0000e+00
# Epoch 36/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2549678.9619 - binary_accuracy: 0.0000e+00
# Epoch 37/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2549757.3577 - binary_accuracy: 0.0000e+00
# Epoch 38/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2550520.3928 - binary_accuracy: 0.0000e+00
# Epoch 39/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2545234.4058 - binary_accuracy: 0.0000e+00
# Epoch 40/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2547802.1011 - binary_accuracy: 0.0000e+00
# Epoch 41/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2548052.4033 - binary_accuracy: 0.0000e+00
# Epoch 42/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2552785.7052 - binary_accuracy: 0.0000e+00
# Epoch 43/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2553571.4757 - binary_accuracy: 0.0000e+00
# Epoch 44/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2551632.0409 - binary_accuracy: 0.0000e+00
# Epoch 45/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2544712.7829 - binary_accuracy: 0.0000e+00
# Epoch 46/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2553063.9412 - binary_accuracy: 0.0000e+00
# Epoch 47/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2548121.5646 - binary_accuracy: 0.0000e+00
# Epoch 48/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2550092.8511 - binary_accuracy: 0.0000e+00
# Epoch 49/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2549712.1453 - binary_accuracy: 0.0000e+00
# Epoch 50/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2546155.3102 - binary_accuracy: 0.0000e+00
# Epoch 51/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2549927.8555 - binary_accuracy: 0.0000e+00
# Epoch 52/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2546998.0423 - binary_accuracy: 0.0000e+00
# Epoch 53/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2549263.0395 - binary_accuracy: 0.0000e+00
# Epoch 54/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2545809.1472 - binary_accuracy: 0.0000e+00
# Epoch 55/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2546175.4152 - binary_accuracy: 0.0000e+00
# Epoch 56/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2547237.4351 - binary_accuracy: 0.0000e+00
# Epoch 57/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2547947.6577 - binary_accuracy: 0.0000e+00
# Epoch 58/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2548271.6820 - binary_accuracy: 0.0000e+00
# Epoch 59/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2547390.2633 - binary_accuracy: 0.0000e+00
# Epoch 60/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2551778.0696 - binary_accuracy: 0.0000e+00
# Epoch 61/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2549025.9459 - binary_accuracy: 0.0000e+00
# Epoch 62/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2553880.5605 - binary_accuracy: 0.0000e+00
# Epoch 63/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2548033.2801 - binary_accuracy: 0.0000e+00
# Epoch 64/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2549681.7655 - binary_accuracy: 0.0000e+00
# Epoch 65/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2544956.6630 - binary_accuracy: 0.0000e+00
# Epoch 66/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2547251.6459 - binary_accuracy: 0.0000e+00
# Epoch 67/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2550700.7992 - binary_accuracy: 0.0000e+00
# Epoch 68/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2550682.4840 - binary_accuracy: 0.0000e+00
# Epoch 69/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2546499.4309 - binary_accuracy: 0.0000e+00
# Epoch 70/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2547048.3718 - binary_accuracy: 0.0000e+00
# Epoch 71/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2545686.2461 - binary_accuracy: 0.0000e+00
# Epoch 72/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2546532.3740 - binary_accuracy: 0.0000e+00
# Epoch 73/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2555135.7586 - binary_accuracy: 0.0000e+00
# Epoch 74/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2547487.2116 - binary_accuracy: 0.0000e+00
# Epoch 75/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2551499.7315 - binary_accuracy: 0.0000e+00
# Epoch 76/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2550352.2169 - binary_accuracy: 0.0000e+00
# Epoch 77/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2551729.9682 - binary_accuracy: 0.0000e+00
# Epoch 78/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2552439.7285 - binary_accuracy: 0.0000e+00
# Epoch 79/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2549767.1296 - binary_accuracy: 0.0000e+00
# Epoch 80/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2550174.8268 - binary_accuracy: 0.0000e+00
# Epoch 81/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2543912.1099 - binary_accuracy: 0.0000e+00
# Epoch 82/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2553293.0133 - binary_accuracy: 0.0000e+00
# Epoch 83/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2548107.1119 - binary_accuracy: 0.0000e+00
# Epoch 84/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2547097.1160 - binary_accuracy: 0.0000e+00
# Epoch 85/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2546090.4580 - binary_accuracy: 0.0000e+00
# Epoch 86/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2548287.7669 - binary_accuracy: 0.0000e+00
# Epoch 87/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2543958.7227 - binary_accuracy: 0.0000e+00
# Epoch 88/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2545809.8583 - binary_accuracy: 0.0000e+00
# Epoch 89/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2551249.9387 - binary_accuracy: 0.0000e+00
# Epoch 90/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2553476.9953 - binary_accuracy: 0.0000e+00
# Epoch 91/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2548930.3238 - binary_accuracy: 0.0000e+00
# Epoch 92/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2545533.9097 - binary_accuracy: 0.0000e+00
# Epoch 93/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2544019.8691 - binary_accuracy: 0.0000e+00
# Epoch 94/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2547867.3340 - binary_accuracy: 0.0000e+00
# Epoch 95/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2553427.9865 - binary_accuracy: 0.0000e+00
# Epoch 96/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2554323.3552 - binary_accuracy: 0.0000e+00
# Epoch 97/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2555007.3831 - binary_accuracy: 0.0000e+00
# Epoch 98/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2549999.0169 - binary_accuracy: 0.0000e+00
# Epoch 99/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2549232.7867 - binary_accuracy: 0.0000e+00
# Epoch 100/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2545733.7138 - binary_accuracy: 0.0000e+00
# Epoch 101/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2550200.7790 - binary_accuracy: 0.0000e+00
# Epoch 102/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2550013.3343 - binary_accuracy: 0.0000e+00
# Epoch 103/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2546681.3003 - binary_accuracy: 0.0000e+00
# Epoch 104/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2547567.0751 - binary_accuracy: 0.0000e+00
# Epoch 105/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2549318.8301 - binary_accuracy: 0.0000e+00
# Epoch 106/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2547207.5036 - binary_accuracy: 0.0000e+00
# Epoch 107/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2554336.7298 - binary_accuracy: 0.0000e+00
# Epoch 108/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2555225.1760 - binary_accuracy: 0.0000e+00
# Epoch 109/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2546512.1856 - binary_accuracy: 0.0000e+00
# Epoch 110/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2544363.2218 - binary_accuracy: 0.0000e+00
# Epoch 111/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2548363.7702 - binary_accuracy: 0.0000e+00
# Epoch 112/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2545037.2481 - binary_accuracy: 0.0000e+00
# Epoch 113/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2549250.1870 - binary_accuracy: 0.0000e+00
# Epoch 114/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2547941.2970 - binary_accuracy: 0.0000e+00
# Epoch 115/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2550067.5950 - binary_accuracy: 0.0000e+00
# Epoch 116/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2551059.5326 - binary_accuracy: 0.0000e+00
# Epoch 117/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2549384.0113 - binary_accuracy: 0.0000e+00
# Epoch 118/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2552634.8895 - binary_accuracy: 0.0000e+00
# Epoch 119/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2546892.1561 - binary_accuracy: 0.0000e+00
# Epoch 120/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2553938.9033 - binary_accuracy: 0.0000e+00
# Epoch 121/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2549592.4006 - binary_accuracy: 0.0000e+00
# Epoch 122/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2551109.4804 - binary_accuracy: 0.0000e+00
# Epoch 123/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2547192.5215 - binary_accuracy: 0.0000e+00
# Epoch 124/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2551126.3804 - binary_accuracy: 0.0000e+00
# Epoch 125/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2550220.8652 - binary_accuracy: 0.0000e+00
# Epoch 126/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2549716.0506 - binary_accuracy: 0.0000e+00
# Epoch 127/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2551077.1555 - binary_accuracy: 0.0000e+00
# Epoch 128/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2548788.9257 - binary_accuracy: 0.0000e+00
# Epoch 129/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2550647.4420 - binary_accuracy: 0.0000e+00
# Epoch 130/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2553969.2638 - binary_accuracy: 0.0000e+00
# Epoch 131/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2553809.4119 - binary_accuracy: 0.0000e+00
# Epoch 132/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2554106.7635 - binary_accuracy: 0.0000e+00
# Epoch 133/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2547740.6541 - binary_accuracy: 0.0000e+00
# Epoch 134/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2548965.5682 - binary_accuracy: 0.0000e+00
# Epoch 135/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2549997.6434 - binary_accuracy: 0.0000e+00
# Epoch 136/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2548377.6691 - binary_accuracy: 0.0000e+00
# Epoch 137/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2542128.7970 - binary_accuracy: 0.0000e+00
# Epoch 138/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2551727.1448 - binary_accuracy: 0.0000e+00
# Epoch 139/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2555169.5680 - binary_accuracy: 0.0000e+00
# Epoch 140/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2549419.5285 - binary_accuracy: 0.0000e+00
# Epoch 141/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2547021.1483 - binary_accuracy: 0.0000e+00
# Epoch 142/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2553655.0464 - binary_accuracy: 0.0000e+00
# Epoch 143/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2546093.2199 - binary_accuracy: 0.0000e+00
# Epoch 144/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2551287.0796 - binary_accuracy: 0.0000e+00
# Epoch 145/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2544272.9787 - binary_accuracy: 0.0000e+00
# Epoch 146/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2550004.3461 - binary_accuracy: 0.0000e+00
# Epoch 147/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2549541.8285 - binary_accuracy: 0.0000e+00
# Epoch 148/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2544968.3091 - binary_accuracy: 0.0000e+00
# Epoch 149/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2547066.9649 - binary_accuracy: 0.0000e+00
# Epoch 150/150
# 904/904 [==============================] - 2s 2ms/step - loss: 2554667.9287 - binary_accuracy: 0.0000e+00

# %% [markdown]
# **Activation Function other than relu we have are :**
#
# **Sigmoid**
#
# **Threshold**
#
# **Hyperbolic Tangent**

# %% [markdown]
# ![](https://i.imgur.com/rFI1tIk.gif)

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([[-1099.0193],
#        [-1070.2235],
#        [-4626.1562],
#        ...,
#        [-5124.3203],
#        [-3814.3445],
#        [-1743.2958]], dtype=float32)

# %%
# convert the training history to a dataframe
history_df = pd.DataFrame(history.history)
# use Pandas native plot method
history_df['loss'].plot()
# Out:
# <AxesSubplot:>

# %%
model.summary()
# Out:
# Model: "Model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (Dense)          (None, 80)                160
# _________________________________________________________________
# dense_layer1 (Dense)         (None, 60)                4860
# _________________________________________________________________
# dense_layer2 (Dense)         (None, 40)                2440
# _________________________________________________________________
# Output_layer (Dense)         (None, 1)                 41
# =================================================================
# Total params: 7,501
# Trainable params: 7,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, show_shapes = True)

# %% [markdown]
# ![](https://i.imgur.com/tHiVFnM.png)

# %%
history_df = pd.DataFrame(history.history)
# Start the plot at epoch 5
history_df.loc[5:, ['loss']].plot()
history_df.loc[5:, ['binary_accuracy']].plot()
print(("Best Validation Loss: {:0.4f}" +\
      "\nBest Validation Accuracy: {:0.4f}")\
      .format(history_df['loss'].min(), 
              history_df['binary_accuracy'].max()))
# Out:
# Best Validation Loss: 2549274.7500
# Best Validation Accuracy: 0.0000

# %% [markdown]
# ![](https://i.imgur.com/eP0gppr.png)

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True,
)

# %%
model.evaluate(X_test,y_test)
# Out:
# 3098/3098 [==============================] - 3s 786us/step - loss: 2545567.2500 - binary_accuracy: 1.0089e-05
# [2545567.25, 1.0088882845593616e-05]

# %% [markdown]
# # **If u like this notebook please appreciate it with a upvote !!**
